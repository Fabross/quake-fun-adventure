# %%
import pandas as pd
import seaborn as sns

# %%
tsunami = pd.read_csv('data/tsunamis.csv')
display(quakedf.describe())
display(quakedf.head())
display(quakedf.info())
# Out:
#                 ID         YEAR        MONTH          DAY         HOUR  \
# count  2654.000000  2654.000000  2510.000000  2404.000000  1363.000000
# mean   2228.544084  1810.496986     6.631076    15.628120    11.327219
# std    1630.843644   347.141742     3.473660     8.666848     6.954016
# min       1.000000 -2000.000000     1.000000     1.000000     0.000000
# 25%     959.250000  1821.000000     4.000000     8.000000     5.000000
# 50%    1836.500000  1897.000000     7.000000    16.000000    11.000000
# 75%    3284.750000  1959.750000    10.000000    23.000000    17.500000
# max    5715.000000  2019.000000    12.000000    31.000000    23.000000
#
#             MINUTE      SECOND  EVENT_VALIDITY   CAUSE_CODE  FOCAL_DEPTH  ...  \
# count  1278.000000  880.000000     2654.000000  2650.000000   905.000000  ...
# mean     28.476526   27.071023        2.354936     1.829057    36.514917  ...
# std      17.192512   18.082654        1.551922     2.305439    41.108534  ...
# ...

# %% [markdown]
# ## Most useful features of the dataset
#
# | Feature         | Type         | Typical Values  | Description                                                                                                                  | Modified?                                             |
# |:----------------|--------------|-----------------|------------------------------------------------------------------------------------------------------------------------------|-------------------------------------------------------|
# | YEAR            | Integer | -               | Year in Universal Coordinated Time (also known as Greenwich Mean Time).                                                                                                 | Yes, just the syntax, so we could plot it more easily |
# | MONTH            | Integer | -               | Month in Universal Coordinated Time (also known as Greenwich Mean Time).                                                                                                 | Yes, just the syntax, so we could plot it more easily |
# | DAY            | Integer | -               | Day in Universal Coordinated Time (also known as Greenwich Mean Time).                                                                                                 | Yes, just the syntax, so we could plot it more easily |
# | HOUR            | Integer | -               | Hour in Universal Coordinated Time (also known as Greenwich Mean Time).                                                                                                 | Yes, just the syntax, so we could plot it more easily |
# | MINUTE            | Integer | -               | Minute in Universal Coordinated Time (also known as Greenwich Mean Time).                                                                                                 | Yes, just the syntax, so we could plot it more easily |
# | SECOND            | Integer | -               | Second in Universal Coordinated Time (also known as Greenwich Mean Time).                                                                                                 | Yes, just the syntax, so we could plot it more easily |
# | CAUSE_CODE            | Integer | -               |          0 = Unknown;        1 = Earthquake;        2 = Questionable Earthquake ;        3 = Earthquake and Landslide ;        4 = Volcano and Earthquake ;        5 = Volcano, Earthquake, and Landslide ;        6 = Volcano ;        7 = Volcano and Landslide ;        8 = Landslide ;        9 = Meteorological ;        10 = Explosion ;        11 = Astronomical Tide                                                                                                | - |
# | LATITUDE        | Decimal      | [-90.0, 90.0]   | Typical values                                                                                                               |                                                       |
# | LONGITUDE       | Decimal      | [-180.0, 180.0] | Typical values                                                                                                               |                                                       |
# | FOCAL_DEPTH           | Decimal      | [0, 700]       | The depth of the earthquake is given in kilometers.                                                                                                   |                                                       |
# | PRIMARY_MAGNITUDE             | Decimal      | [0.0, 9.9]    | The value in this column contains the primary earthquake magnitude                                                                                                       |                                                       |
# | LOCATION_NAME     | Categorical  | -               | The Country, State, Province or Island where the tsunami source occurred (For example enter: Japan or Honshu)                                                                                             |                                   |
# | STATE             | Categorical      | -    | The two-letter State or Province abbreviation where the Earthquake occurred.                         | Yes                                                   |
# | COUNTRY            | Categorical      | -      |  The Country where the tsunami source occurred (For example enter: Japan or Russia) .                                        | Yes                                                   |
# | REGION_CODE             | Categorical      | -     | Regional boundaries are based on frequency of occurrence of tsunamigenic events, geophysical relations, risk in distant areas and political justification. 77 = 	West Coast of Africa; 78 = 	Central Africa; 73 = 	Northeast Atlantic Ocean; 72 = 	Northwest Atlantic Ocean; 70 = 	Southeast Atlantic Ocean; 71 = 	Southwest Atlantic Ocean; 75 = 	E. Coast USA and Canada, St Pierre and Miquelon; 76 = 	Gulf of Mexico; 74 = 	Caribbean Sea; 40 = 	Black Sea and Caspian Sea; 50 = 	Mediterranean Sea; 30 = 	Red Sea and Persian Gulf; 60 = 	Indian Ocean (including west coast of Australia); 87 = 	Alaska (including Aleutian Islands); 84 = 	China, North and South Korea, Philippines, Taiwan; 81 = 	E. Coast Australia, New Zealand, South Pacific Is.; 80 = 	Hawaii, Johnston Atoll, Midway I; 83 = 	E. Indonesia (Pacific Ocean) and Malaysia; 82 = 	New Caledonia, New Guinea, Solomon Is., Vanuatu; 86 = 	Kamchatka and Kuril Islands; 85 = 	Japan; 88 = 	West Coast of North and Central America; 89 = 	West Coast of South America  |                                                       |
# | EVENT_VALIDITY | Categorical      | -        |  Validity of the actual tsunami occurrence is indicated by a numerical rating of the reports of that event: 4 = definite tsunami ;        3 = probable tsunami ;        2 = questionable tsunami ;        1 = very doubtful tsunami ;        0 = event that only caused a seiche or disturbance in an inland river ;        -1 = erroneous entry                                                       |                                                       |
#
# Estas serán las columnas a utilizar en este proyecto, el resto se descartará.

# %%
cols = ['YEAR', 'MONTH', 'DAY', 'CAUSE_CODE', 'LATITUDE',
       'LONGITUDE', 'PRIMARY_MAGNITUDE', 'COUNTRY', 'EVENT_VALIDITY']
chiledf = tsunami[tsunami['COUNTRY'] == 'CHILE'][cols].copy()

# %% [markdown]
# No se utiliza STATE debido a que contiene puros valores NaN.
# Supuestos:
# 1. No existe la posibilidad de que en el mismo tiempo haya mas de un tsunami en las misma coordenada y en distinta profundidad.
# 2. Se obtienen datos solo de Chile, por lo tanto se descartan las columnas de LOCATION_NAME y REGION_CODE
#
# ### Limpieza de los datos
# Se verifica cuantos datos NaN existen en las columnas

# %%
chiledf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 166 entries, 151 to 2651
# Data columns (total 9 columns):
# YEAR                 166 non-null int64
# MONTH                164 non-null float64
# DAY                  164 non-null float64
# CAUSE_CODE           166 non-null float64
# LATITUDE             155 non-null object
# LONGITUDE            155 non-null object
# PRIMARY_MAGNITUDE    106 non-null float64
# COUNTRY              166 non-null object
# EVENT_VALIDITY       166 non-null int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 13.0+ KB

# %%
chiledf = chiledf.dropna(subset=['LATITUDE', 'LONGITUDE', 'PRIMARY_MAGNITUDE'])

# %%
chiledf
# Out:
#       YEAR  MONTH   DAY  CAUSE_CODE LATITUDE LONGITUDE  PRIMARY_MAGNITUDE  \
# 198   1562   10.0  28.0         1.0    -38.7     -73.5                8.0
# 200   1570    2.0   8.0         1.0   -36.75       -73                8.3
# 205   1575   12.0  16.0         1.0    -39.8     -73.2                8.5
# 242   1615    9.0  16.0         1.0    -18.5    -70.35                7.5
# 288   1657    3.0  15.0         1.0   -36.83    -73.03                8.0
# 333   1681    3.0  10.0         1.0    -18.5    -70.35                7.5
# 341   1687    7.0  12.0         1.0    -32.8     -70.7                7.5
# 408   1730    7.0   8.0         1.0    -32.5     -71.5                9.1
# 421   1737   12.0  24.0         1.0      -43       -74                8.0
# 443   1751    5.0  25.0         1.0      -37       -73                8.5
# 650   1819    4.0  12.0         1.0      -27     -71.5                8.5
# 671   1822   11.0  20.0         1.0      -33       -72                8.5
# ...

# %% [markdown]
# ## Se filtran los datos no numéricos, se transforma la variable categórica magType para distinguir entre magnitudes:
# 'mb':0,'mwr':1,'mww':2,'ml':3,'md':4,'mb_lg':5
#
# Buscar qué significan

# %%
def coding(col, codeDict):
  colCoded = pd.Series(col, copy=True)
  for key, value in codeDict.items():
    colCoded.replace(key, value, inplace=True)
  return colCoded
quakedf["new_magType"] = coding(quakedf["magType"], {'mb':0,'mwr':1,'mww':2,'ml':3,'md':4,'mb_lg':5})
display(pd.value_counts(quakedf["new_magType"]))
# Out:
# 0    2805
# 1    1039
# 2     301
# 3     157
# 4      15
# 5       1
# Name: new_magType, dtype: int64

# %%
numerical_feature_df=quakedf[['latitude', 'longitude', 'depth', 'mag', 'new_magType',
       'gap', 'dmin', 'rms',
       'horizontalError', 'depthError', 'magError', 'magNst']]

# %% [markdown]
# ## Se hace matriz de correlación para el estudio de las features

# %%
corrmatrix=numerical_feature_df.corr()
sns.heatmap(corrmatrix, robust=True, annot=True)
