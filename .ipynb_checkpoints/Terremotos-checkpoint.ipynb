# %%
import pandas as pd

# %%
quakedf = pd.read_csv('data/chile.csv')
display(quakedf.describe())
display(quakedf.head())
# Out:
#           latitude    longitude        depth          mag  nst          gap  \
# count  4318.000000  4318.000000  4318.000000  4318.000000  0.0  3974.000000
# mean    -28.199848   -70.542696    71.680783     4.387355  NaN   107.263714
# std       5.743812     1.990156    64.887232     0.430155  NaN    51.543700
# min     -54.249800   -76.304800     1.000000     2.500000  NaN    13.000000
# 25%     -31.730300   -71.980775    18.362500     4.100000  NaN    62.000000
# 50%     -30.260900   -71.325800    41.055000     4.300000  NaN    98.000000
# 75%     -23.053300   -68.894575   114.435000     4.500000  NaN   147.000000
# max     -17.227200   -66.797000   286.440000     8.300000  NaN   274.000000
#
#               dmin          rms  horizontalError   depthError     magError  \
# count  3974.000000  4318.000000       4318.00000  4318.000000  3829.000000
# mean      0.820601     0.884567          5.81415     6.046642     0.171197
# ...

# %%
quakedf.columns
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type',
#        'horizontalError', 'depthError', 'magError', 'magNst', 'status',
#        'locationSource', 'magSource'],
#       dtype='object')
